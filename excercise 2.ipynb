# %%
import pandas as pd
import numpy as np

# %%
scores = pd.read_csv("https://raw.githubusercontent.com/OpenClassrooms-Student-Center/en-8253136-Use-Python-Libraries-for-Data-Science/main/quizdata/scores.csv")

# %%
math_data = scores.loc[scores["subject"] == "Math"]

# %%
round(math_data["score"].mean(), 2)
# Out:
# 11.33

# %%
data.groupby("name").agg({"subject": "mean"})
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py:1578, in GroupBy._cython_agg_general.<locals>.array_func(values)
#    1577 try:
# -> 1578     result = self.grouper._cython_operation(
#    1579         "aggregate", values, how, axis=data.ndim - 1, min_count=min_count
#    1580     )
#    1581 except NotImplementedError:
#    1582     # generally if we have numeric_only=False
#    1583     # and non-applicable functions
#    1584     # try to python agg
#    1585     # TODO: shouldn't min_count matter?
#
# File ~\anaconda3\lib\site-packages\pandas\core\groupby\ops.py:939, in BaseGrouper._cython_operation(self, kind, values, how, axis, min_count, **kwargs)
#     938 ngroups = self.ngroups
# --> 939 return cy_op.cython_operation(
#     940     values=values,
#     941     axis=axis,
# ...

# %%
scores.loc[((scores['subject'] == 'Math') | (scores['subject'] == 'Physics/Chemistry')) & (scores['score'] >= 15), 'name']
# Out:
# 22        Mary Johnson
# 23       William Brown
# 28      Michael Taylor
# 30    Richard Williams
# 31     Elizabeth Perez
# 32         David Jones
# 65       William Brown
# 68     Robert Martinez
# 70      Michael Taylor
# 74         David Jones
# 78        Karen Wilson
# 81           Ron Clark
# 82           Lisa Hall
# Name: name, dtype: object

# %%
scores.pivot_table(index='name', columns='subject', values='score').head()
# Out:
# subject          Biology  English  Math  Physics/Chemistry
# name
# Barbara White          7       16     6                  5
# Charles Gomez         17       19     6                 12
# David Jones           11       10    19                 15
# Diane Morales         14       19    11                  6
# Elizabeth Perez       15       13    19                  8

# %%
products = pd.read_csv("https://raw.githubusercontent.com/OpenClassrooms-Student-Center/en-8253136-Use-Python-Libraries-for-Data-Science/main/quizdata/products.csv")

# %%
products.head()
# Out:
#    id  price
# 0   0   24.8
# 1   1   13.1
# 2   2   23.7
# 3   3   16.0
# 4   4   19.0

# %%
orders = pd.read_csv("https://raw.githubusercontent.com/OpenClassrooms-Student-Center/en-8253136-Use-Python-Libraries-for-Data-Science/main/quizdata/orders.csv")

# %%
orders.head()
# Out:
#    id  quantity
# 0  70         2
# 1  41         4
# 2  72         2
# 3  92         8
# 4  73         1

# %%
sales = pd.merge(products, orders , on = "id")

# %%
sales.head()
# Out:
#    id  price  quantity  total
# 0   0   24.8         8  198.4
# 1   0   24.8         1   24.8
# 2   0   24.8         4   99.2
# 3   0   24.8         4   99.2
# 4   0   24.8         1   24.8

# %%
sales["total"] =  sales["price"] * sales["quantity"]

# %%
sales
# Out:
#      id  price  quantity  total
# 0     0   24.8         8  198.4
# 1     0   24.8         1   24.8
# 2     0   24.8         4   99.2
# 3     0   24.8         4   99.2
# 4     0   24.8         1   24.8
# ..   ..    ...       ...    ...
# 995  99   11.8         8   94.4
# 996  99   11.8         1   11.8
# 997  99   11.8         9  106.2
# 998  99   11.8         9  106.2
# 999  99   11.8         3   35.4
#
# [1000 rows x 4 columns]

# %%
sales.loc
# Out:
#     total  price
# id
# 0    24.8   24.8
# 1    13.1   13.1
# 2    23.7   23.7
# 3    16.0   16.0
# 4    19.0   19.0
# ..    ...    ...
# 95   21.2   21.2
# 96   18.8   18.8
# 97    8.9    8.9
# 98   20.0   20.0
# 99   11.8   11.8
#
# [100 rows x 2 columns]

# %%
sales.sort_values("total")
# Out:
#      id  price  quantity  total
# 936  94    5.8         1    5.8
# 949  94    5.8         1    5.8
# 948  94    5.8         1    5.8
# 926  92    7.4         1    7.4
# 574  55    8.0         1    8.0
# ..   ..    ...       ...    ...
# 796  79   33.3         8  266.4
# 794  79   33.3         8  266.4
# 622  61   30.0         9  270.0
# 618  61   30.0         9  270.0
# 549  52   32.4         9  291.6
#
# [1000 rows x 4 columns]
