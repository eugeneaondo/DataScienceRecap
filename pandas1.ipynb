# %%
import pandas as pd

# %%
data_csv=pd.read_csv('customers.csv')

# %%
data_csv.head()
# Out:
#    identifier                     email             name gender
# 0           0       JohnSmith@rhyta.com       John Smith      M
# 1           1   MaryJohnson@fleckens.hu     Mary Johnson      F
# 2           2   WilliamBrown@einrot.com    William Brown      M
# 3           3      JamesLee@armyspy.com        James Lee      M
# 4           4  PatriciaGarcia@rhyta.com  Patricia Garcia      F

# %%
data_csv.tail()
# Out:
#      identifier                      email            name gender
# 145         145  ClarenceBurke@teleworm.us  Clarence Burke      M
# 146         146     LorraineNunez@cuvox.de  Lorraine Nunez      F
# 147         147       TeddyJordan@cuvox.de    Teddy Jordan      M
# 148         148     DeannaWelch@dayrep.com    Deanna Welch      F
# 149         149   BrianFrontino@einrot.com  Brian Frontino      M

# %%
data_json = pd.read_json('customers.json')
data_json.head()
# Out:
#    identifier                     email             name gender
# 0           0       JohnSmith@rhyta.com       John Smith      M
# 1           1   MaryJohnson@fleckens.hu     Mary Johnson      F
# 2           2   WilliamBrown@einrot.com    William Brown      M
# 3           3      JamesLee@armyspy.com        James Lee      M
# 4           4  PatriciaGarcia@rhyta.com  Patricia Garcia      F

# %%
data_excel = pd.read_excel('customers.xlsx')
data_excel.tail()
# Out:
#      identifier                      email            name gender
# 145         145  ClarenceBurke@teleworm.us  Clarence Burke      M
# 146         146     LorraineNunez@cuvox.de  Lorraine Nunez      F
# 147         147       TeddyJordan@cuvox.de    Teddy Jordan      M
# 148         148     DeannaWelch@dayrep.com    Deanna Welch      F
# 149         149   BrianFrontino@einrot.com  Brian Frontino      M

# %%
display(data_csv.head())
# Out:
#    identifier                     email             name gender
# 0           0       JohnSmith@rhyta.com       John Smith      M
# 1           1   MaryJohnson@fleckens.hu     Mary Johnson      F
# 2           2   WilliamBrown@einrot.com    William Brown      M
# 3           3      JamesLee@armyspy.com        James Lee      M
# 4           4  PatriciaGarcia@rhyta.com  Patricia Garcia      F

# %%
display(data_json.tail(3))
# Out:
#      identifier                     email            name gender
# 147         147      TeddyJordan@cuvox.de    Teddy Jordan      M
# 148         148    DeannaWelch@dayrep.com    Deanna Welch      F
# 149         149  BrianFrontino@einrot.com  Brian Frontino      M

# %%
data_json.shape
# Out:
# (150, 4)

# %%
data_json.dtypes
# Out:
# identifier     int64
# email         object
# name          object
# gender        object
# dtype: object

# %%
customer_arr = data_json.values
display(customer_arr)
# Out:
# array([[0, 'JohnSmith@rhyta.com', 'John Smith', 'M'],
#        [1, 'MaryJohnson@fleckens.hu', 'Mary Johnson', 'F'],
#        [2, 'WilliamBrown@einrot.com', 'William Brown', 'M'],
#        [3, 'JamesLee@armyspy.com', 'James Lee', 'M'],
#        [4, 'PatriciaGarcia@rhyta.com', 'Patricia Garcia', 'F'],
#        [5, 'RobertMartinez@cuvox.de', 'Robert Martinez', 'M'],
#        [6, 'LindaRodriguez@dayrep.com', 'Linda Rodriguez', 'F'],
#        [7, 'MichaelTaylor@armyspy.com', 'Michael Taylor', 'M'],
#        [8, 'BarbaraWhite@fleckens.hu', 'Barbara White', 'F'],
#        [9, 'RichardWilliams@teleworm.us', 'Richard Williams', 'M'],
#        [10, 'ElizabethPerez@jourrapide.com', 'Elizabeth Perez', 'F'],
#        [11, 'DavidJones@einrot.com', 'David Jones', 'M'],
#        [12, 'JosephMiller@armyspy.com', 'Joseph Miller', 'M'],
#        [13, 'SusanDavis@jourrapide.com', 'Susan Davis', 'F'],
#        [14, 'CharlesGomez@superrito.com', 'Charles Gomez', 'M'],
# ...

# %%
customer_arr[0,:]
# Out:
# array([0, 'JohnSmith@rhyta.com', 'John Smith', 'M'], dtype=object)

# %%
customer_arr[1,]
# Out:
# 'Mary Johnson'

# %%
customer_arr[:,1]
# Out:
# array(['JohnSmith@rhyta.com', 'MaryJohnson@fleckens.hu',
#        'WilliamBrown@einrot.com', 'JamesLee@armyspy.com',
#        'PatriciaGarcia@rhyta.com', 'RobertMartinez@cuvox.de',
#        'LindaRodriguez@dayrep.com', 'MichaelTaylor@armyspy.com',
#        'BarbaraWhite@fleckens.hu', 'RichardWilliams@teleworm.us',
#        'ElizabethPerez@jourrapide.com', 'DavidJones@einrot.com',
#        'JosephMiller@armyspy.com', 'SusanDavis@jourrapide.com',
#        'CharlesGomez@superrito.com', 'KarenWilson@jourrapide.com',
#        'JoseSanchez@teleworm.us', 'DianeMorales@cuvox.de',
#        'RonClark@teleworm.us', 'LisaHall@cuvox.de',
#        'PaulTorres@teleworm.us', 'NancyThomas@superrito.com',
#        'StevenWright@cuvox.de', 'DonnaHernandez@dayrep.com',
#        'FrankJackson@cuvox.de', 'CarolLopez@jourrapide.com',
#        'MarkHarris@teleworm.us', 'LauraNelson@teleworm.us',
#        'AnthonyYoung@armyspy.com', 'MelissaGonzalez@armyspy.com',
# ...

# %%
data_json["email"]
# Out:
# 0            JohnSmith@rhyta.com
# 1        MaryJohnson@fleckens.hu
# 2        WilliamBrown@einrot.com
# 3           JamesLee@armyspy.com
# 4       PatriciaGarcia@rhyta.com
#                  ...
# 145    ClarenceBurke@teleworm.us
# 146       LorraineNunez@cuvox.de
# 147         TeddyJordan@cuvox.de
# 148       DeannaWelch@dayrep.com
# 149     BrianFrontino@einrot.com
# Name: email, Length: 150, dtype: object

# %%
variables = ["name" , "email"]
data_json[variables]
# Out:
#                 name                      email
# 0         John Smith        JohnSmith@rhyta.com
# 1       Mary Johnson    MaryJohnson@fleckens.hu
# 2      William Brown    WilliamBrown@einrot.com
# 3          James Lee       JamesLee@armyspy.com
# 4    Patricia Garcia   PatriciaGarcia@rhyta.com
# ..               ...                        ...
# 145   Clarence Burke  ClarenceBurke@teleworm.us
# 146   Lorraine Nunez     LorraineNunez@cuvox.de
# 147     Teddy Jordan       TeddyJordan@cuvox.de
# 148     Deanna Welch     DeannaWelch@dayrep.com
# 149   Brian Frontino   BrianFrontino@einrot.com
#
# [150 rows x 2 columns]

# %%
data_json["email"]
# Out:
# 0            JohnSmith@rhyta.com
# 1        MaryJohnson@fleckens.hu
# 2        WilliamBrown@einrot.com
# 3           JamesLee@armyspy.com
# 4       PatriciaGarcia@rhyta.com
#                  ...
# 145    ClarenceBurke@teleworm.us
# 146       LorraineNunez@cuvox.de
# 147         TeddyJordan@cuvox.de
# 148       DeannaWelch@dayrep.com
# 149     BrianFrontino@einrot.com
# Name: email, Length: 150, dtype: object

# %%
data_json.head()
data_json.tail()
# Out:
#      identifier                      email            name gender
# 145         100  ClarenceBurke@teleworm.us  Clarence Burke      M
# 146         100     LorraineNunez@cuvox.de  Lorraine Nunez      F
# 147         100       TeddyJordan@cuvox.de    Teddy Jordan      M
# 148         100     DeannaWelch@dayrep.com    Deanna Welch      F
# 149         100   BrianFrontino@einrot.com  Brian Frontino      M

# %%
data_json["identifier"]=1

# %%
data_json["identifier"]
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 145    1
# 146    1
# 147    1
# 148    1
# 149    1
# Name: identifier, Length: 150, dtype: int64

# %%
data_json["identifier"]=data_json["identifier"]*100

# %%
data_json["identifier"]
# Out:
# 0      100
# 1      100
# 2      100
# 3      100
# 4      100
#       ...
# 145    100
# 146    100
# 147    100
# 148    100
# 149    100
# Name: identifier, Length: 150, dtype: int64

# %%
data_json['id']=data_json["identifier"]+1000

# %%
data_json.head()
# Out:
#    identifier                     email             name gender    id
# 0         100       JohnSmith@rhyta.com       John Smith      M  1100
# 1         100   MaryJohnson@fleckens.hu     Mary Johnson      F  1100
# 2         100   WilliamBrown@einrot.com    William Brown      M  1100
# 3         100      JamesLee@armyspy.com        James Lee      M  1100
# 4         100  PatriciaGarcia@rhyta.com  Patricia Garcia      F  1100

# %%
data_json["town"]="Nairobi"

# %%
data_json.head()
# Out:
#    identifier                     email             name gender    id     town
# 0         100       JohnSmith@rhyta.com       John Smith      M  1100  Nairobi
# 1         100   MaryJohnson@fleckens.hu     Mary Johnson      F  1100  Nairobi
# 2         100   WilliamBrown@einrot.com    William Brown      M  1100  Nairobi
# 3         100      JamesLee@armyspy.com        James Lee      M  1100  Nairobi
# 4         100  PatriciaGarcia@rhyta.com  Patricia Garcia      F  1100  Nairobi

# %%
data_json.drop(columns="id")
# Out:
#      identifier                      email             name gender     town
# 0           100        JohnSmith@rhyta.com       John Smith      M  Nairobi
# 1           100    MaryJohnson@fleckens.hu     Mary Johnson      F  Nairobi
# 2           100    WilliamBrown@einrot.com    William Brown      M  Nairobi
# 3           100       JamesLee@armyspy.com        James Lee      M  Nairobi
# 4           100   PatriciaGarcia@rhyta.com  Patricia Garcia      F  Nairobi
# ..          ...                        ...              ...    ...      ...
# 145         100  ClarenceBurke@teleworm.us   Clarence Burke      M  Nairobi
# 146         100     LorraineNunez@cuvox.de   Lorraine Nunez      F  Nairobi
# 147         100       TeddyJordan@cuvox.de     Teddy Jordan      M  Nairobi
# 148         100     DeannaWelch@dayrep.com     Deanna Welch      F  Nairobi
# 149         100   BrianFrontino@einrot.com   Brian Frontino      M  Nairobi
#
# [150 rows x 5 columns]

# %%
del data_json["town"]

# %%
data_json.head()
# Out:
#    identifier                     email             name gender    id
# 0         100       JohnSmith@rhyta.com       John Smith      M  1100
# 1         100   MaryJohnson@fleckens.hu     Mary Johnson      F  1100
# 2         100   WilliamBrown@einrot.com    William Brown      M  1100
# 3         100      JamesLee@armyspy.com        James Lee      M  1100
# 4         100  PatriciaGarcia@rhyta.com  Patricia Garcia      F  1100

# %%
data_json.pop("id")
# Out:
# 0      1100
# 1      1100
# 2      1100
# 3      1100
# 4      1100
#        ...
# 145    1100
# 146    1100
# 147    1100
# 148    1100
# 149    1100
# Name: id, Length: 150, dtype: int64

# %%
data_json.head()
# Out:
#    identifier                     email             name gender
# 0         100       JohnSmith@rhyta.com       John Smith      M
# 1         100   MaryJohnson@fleckens.hu     Mary Johnson      F
# 2         100   WilliamBrown@einrot.com    William Brown      M
# 3         100      JamesLee@armyspy.com        James Lee      M
# 4         100  PatriciaGarcia@rhyta.com  Patricia Garcia      F

# %%
data_json.rename(columns={"identifier" : "user_id"})
# Out:
#      user_id                      email             name gender
# 0        100        JohnSmith@rhyta.com       John Smith      M
# 1        100    MaryJohnson@fleckens.hu     Mary Johnson      F
# 2        100    WilliamBrown@einrot.com    William Brown      M
# 3        100       JamesLee@armyspy.com        James Lee      M
# 4        100   PatriciaGarcia@rhyta.com  Patricia Garcia      F
# ..       ...                        ...              ...    ...
# 145      100  ClarenceBurke@teleworm.us   Clarence Burke      M
# 146      100     LorraineNunez@cuvox.de   Lorraine Nunez      F
# 147      100       TeddyJordan@cuvox.de     Teddy Jordan      M
# 148      100     DeannaWelch@dayrep.com     Deanna Welch      F
# 149      100   BrianFrontino@einrot.com   Brian Frontino      M
#
# [150 rows x 4 columns]

# %%
data_json.sort_values("name")
# Out:
#      identifier                      email            name gender
# 133         100  AlbertoLittle@armyspy.com  Alberto Little      M
# 123         100    AlfredoFields@rhyta.com  Alfredo Fields      M
# 68          100  AlicePrice@jourrapide.com     Alice Price      F
# 50          100   AmberBell@jourrapide.com      Amber Bell      F
# 66          100        AmySimmons@cuvox.de     Amy Simmons      F
# ..          ...                        ...             ...    ...
# 113         100     VictorBurns@dayrep.com    Victor Burns      M
# 55          100        VictorGray@cuvox.de     Victor Gray      M
# 41          100       WalterEvans@cuvox.de    Walter Evans      M
# 2           100    WilliamBrown@einrot.com   William Brown      M
# 139         100  WillieMendoza@armyspy.com  Willie Mendoza      M
#
# [150 rows x 4 columns]

# %%
data_json.sort_values("name", ascending=False)
# Out:
#      identifier                      email            name gender
# 139         100  WillieMendoza@armyspy.com  Willie Mendoza      M
# 2           100    WilliamBrown@einrot.com   William Brown      M
# 41          100       WalterEvans@cuvox.de    Walter Evans      M
# 55          100        VictorGray@cuvox.de     Victor Gray      M
# 113         100     VictorBurns@dayrep.com    Victor Burns      M
# ..          ...                        ...             ...    ...
# 66          100        AmySimmons@cuvox.de     Amy Simmons      F
# 50          100   AmberBell@jourrapide.com      Amber Bell      F
# 68          100  AlicePrice@jourrapide.com     Alice Price      F
# 123         100    AlfredoFields@rhyta.com  Alfredo Fields      M
# 133         100  AlbertoLittle@armyspy.com  Alberto Little      M
#
# [150 rows x 4 columns]

# %%
loans = pd.read_csv('https://raw.githubusercontent.com/OpenClassrooms-Student-Center/en-8253136-Use-Python-Libraries-for-Data-Science/main/data/loans.csv')
loans.head()
# Out:
#    identifier           city  zip code  income  repayment  term         type  \
# 0           0        CHICAGO     60100  3669.0    1130.05   240  real estate
# 1           1        DETROIT     48009  5310.0     240.00    64   automobile
# 2           1        DETROIT     48009  5310.0    1247.85   300  real estate
# 3           2  SAN FRANCISCO     94010  1873.0     552.54   240  real estate
# 4           3  SAN FRANCISCO     94010  1684.0     586.03   180  real estate
#
#    interest_rate
# 0          1.168
# 1          3.701
# 2          1.173
# 3          0.972
# 4          1.014

# %%
loans["interest_rate"]=(((loans["repayment"] *  loans["term"])/loans["income"]))
loans["interest_rate"] = loans["interest_rate"].apply(lambda x: round(x, 2))

# %%
loans["debt_to_income"]
# Out:
# 0       73.92
# 1        2.89
# 2       70.50
# 3       70.80
# 4       62.64
#         ...
# 239     73.20
# 240      1.16
# 241     66.96
# 242    137.04
# 243     55.50
# Name: debt_to_income, Length: 244, dtype: float64

# %%
loans.rename(columns={"debt_to_income" : "interest_rate"})
# Out:
#      identifier           city  zip code  income  repayment  term  \
# 0             0        CHICAGO     60100  3669.0    1130.05   240
# 1             1        DETROIT     48009  5310.0     240.00    64
# 2             1        DETROIT     48009  5310.0    1247.85   300
# 3             2  SAN FRANCISCO     94010  1873.0     552.54   240
# 4             3  SAN FRANCISCO     94010  1684.0     586.03   180
# ..          ...            ...       ...     ...        ...   ...
# 239         224        DETROIT     48008  5118.0    1248.79   300
# 240         224        DETROIT     48008  5118.0     238.20    25
# 241         225      BALTIMORE     21100  2356.0     876.43   180
# 242         226        DETROIT     48002  5098.0    2910.96   240
# 243         227        DETROIT     48015  2348.0     434.38   300
#
#             type  interest_rate  interest_rate
# 0    real estate          1.168          73.92
# 1     automobile          3.701           2.89
# ...

# %%
loans["total_cost"] = loans["repayment"] *  loans["term"]

# %%
loans["total_cost"]
# Out:
# 0      271212.0
# 1      383409.0
# 2      383409.0
# 3      132609.6
# 4      105485.4
#          ...
# 239    383409.0
# 240    383409.0
# 241    157757.4
# 242    383409.0
# 243    383409.0
# Name: total_cost, Length: 244, dtype: object

# %%
loans.head()
# Out:
#    identifier           city  zip code  income  repayment  term         type  \
# 0           0        CHICAGO     60100  3669.0    1130.05   240  real estate
# 1           1        DETROIT     48009  5310.0     240.00    64   automobile
# 2           1        DETROIT     48009  5310.0    1247.85   300  real estate
# 3           2  SAN FRANCISCO     94010  1873.0     552.54   240  real estate
# 4           3  SAN FRANCISCO     94010  1684.0     586.03   180  real estate
#
#    interest_rate  debt_to_income  total_cost
# 0          1.168           73.92    271212.0
# 1          3.701            2.89     15360.0
# 2          1.173           70.50    374355.0
# 3          0.972           70.80    132609.6
# 4          1.014           62.64    105485.4

# %%
loans["profit"]=((loans["total_cost"]*loans["interest_rate"]/100)/24)
loans["profit"] = loans["profit"].apply(lambda x: round(x, 2))

# %%
loans.head()
# Out:
#   identifier           city zip code   income repayment   term         type  \
# 0        0.0        CHICAGO  60100.0   3669.0   1130.05  240.0  real estate
# 1    DETROIT        DETROIT  60100.0  60100.0   2130.05    180  real estate
# 2    DETROIT        DETROIT  60100.0  60100.0   2130.05    180  real estate
# 3        2.0  SAN FRANCISCO  94010.0   1873.0    552.54  240.0  real estate
# 4        3.0  SAN FRANCISCO  94010.0   1684.0    586.03  180.0  real estate
#
#    interest_rate debt_to_income total_cost   profit
# 0          73.92      73.919869   271212.0  8353.33
# 1           6.38       6.379517   383409.0  1019.23
# 2           6.38       6.379517   383409.0  1019.23
# 3          70.80      70.800641   132609.6  3911.98
# 4          62.64      62.639786   105485.4  2753.17

# %%
loans.iloc[0,1]
# Out:
# 'CHICAGO'

# %%
loans.iloc[:10, 3]
# Out:
# 0    3669.0
# 1    5310.0
# 2    5310.0
# 3    1873.0
# 4    1684.0
# 5    1476.0
# 6    2476.0
# 7    1867.0
# 8    5486.0
# 9    3578.0
# Name: income, dtype: float64

# %%
loans.iloc[:5, 5:7]
# Out:
#    term         type
# 0   240  real estate
# 1    64   automobile
# 2   300  real estate
# 3   240  real estate
# 4   180  real estate

# %%
loans.loc[loans["income"]>4000 , :]
# Out:
#      identifier           city  zip code  income  repayment  term  \
# 1             1        DETROIT     48009  5310.0     240.00    64
# 2             1        DETROIT     48009  5310.0    1247.85   300
# 8             7  NEW YORK CITY     10000  5486.0    2956.95   300
# 16           15        DETROIT     48003  4109.0    1220.37   240
# 17           16        DETROIT     48001  6118.0    1505.03   240
# ..          ...            ...       ...     ...        ...   ...
# 234         219        DETROIT     48017  6257.0    1820.79   300
# 236         221        DETROIT     48017  4477.0    1356.53   240
# 239         224        DETROIT     48008  5118.0    1248.79   300
# 240         224        DETROIT     48008  5118.0     238.20    25
# 242         226        DETROIT     48002  5098.0    2910.96   240
#
#             type  interest_rate  debt_to_income  total_cost  profit
# 1     automobile          3.701            2.89     15360.0   23.69
# ...

# %%
loans.loc[(loans["income"]>6000) & (loans["city"]=="DETROIT"), :]
# Out:
#      identifier     city  zip code  income  repayment  term         type  \
# 17           16  DETROIT     48001  6118.0    1505.03   240  real estate
# 83           80  DETROIT     48019  6783.0    2197.69   180  real estate
# 89           85  DETROIT     48005  6341.0    2980.27   240  real estate
# 99           95  DETROIT     48016  6069.0     977.11   240  real estate
# 100          95  DETROIT     48016  6069.0     341.40    24   automobile
# 126         119  DETROIT     48019  6274.0    1631.24   180  real estate
# 129         122  DETROIT     48001  6536.0    2457.54   120  real estate
# 137         129  DETROIT     48012  6807.0    1899.15   180  real estate
# 166         154  DETROIT     48014  6040.0    1407.32   240  real estate
# 181         168  DETROIT     48003  6366.0    2807.41   240  real estate
# 186         173  DETROIT     48006  6784.0    3744.77   180  real estate
# 194         181  DETROIT     48002  6439.0    1023.80   300  real estate
# ...

# %%
loans.loc[(loans["type"] == "automobile") & (loans["interest_rate"]>3.0) | (loans["city"] == "SAN FRANCISCO")]
# Out:
#      identifier           city  zip code  income  repayment  term  \
# 1             1        DETROIT     48009  5310.0     240.00    64
# 3             2  SAN FRANCISCO     94010  1873.0     552.54   240
# 4             3  SAN FRANCISCO     94010  1684.0     586.03   180
# 5             4  SAN FRANCISCO     94012  1476.0     423.61   240
# 10            9  SAN FRANCISCO     94012  1386.0     612.61   180
# ..          ...            ...       ...     ...        ...   ...
# 222         208  SAN FRANCISCO     94011  2547.0     962.77   240
# 225         211        CHICAGO     60400  3724.0     215.00    43
# 230         215  SAN FRANCISCO     94006  1266.0     238.01   240
# 235         220  SAN FRANCISCO     94001  2560.0     896.00   300
# 240         224        DETROIT     48008  5118.0     238.20    25
#
#             type  interest_rate  debt_to_income  total_cost  profit
# 1     automobile          3.701            2.89     15360.0   23.69
# ...

# %%
loans.sort_values("type").head()
# Out:
#      identifier           city  zip code  income  repayment  term        type  \
# 225         211        CHICAGO     60400  3724.0      215.0    43  automobile
# 141         133        DETROIT     48011  3099.0      291.2    78  automobile
# 154         144  SAN FRANCISCO     94010  2240.0      316.6    81  automobile
# 100          95        DETROIT     48016  6069.0      341.4    24  automobile
# 172         159        DETROIT     48010  3238.0      315.8    55  automobile
#
#      interest_rate  debt_to_income  total_cost  profit
# 225          3.374            2.48      9245.0   13.00
# 141          3.508            7.33     22713.6   33.20
# 154          3.267           11.45     25644.6   34.91
# 100          3.644            1.35      8193.6   12.44
# 172          2.995            5.36     17369.0   21.68

# %%
loans.iloc[:3, 7]=1.05

# %%
loans.head()
# Out:
#    identifier           city  zip code  income  repayment  term         type  \
# 0           0        CHICAGO     60100  3669.0    1130.05   240  real estate
# 1           1        DETROIT     48009  5310.0     240.00    64   automobile
# 2           1        DETROIT     48009  5310.0    1247.85   300  real estate
# 3           2  SAN FRANCISCO     94010  1873.0     552.54   240  real estate
# 4           3  SAN FRANCISCO     94010  1684.0     586.03   180  real estate
#
#    interest_rate  debt_to_income  total_cost  profit
# 0          1.050           73.92    271212.0  131.99
# 1          1.050            2.89     15360.0   23.69
# 2          1.050           70.50    374355.0  182.97
# 3          0.972           70.80    132609.6   53.71
# 4          1.014           62.64    105485.4   44.57

# %%
loans.loc[(loans["city"] == "DETROIT"), "interest_rate"] = 1.05

# %%
loans.head(5)

# %%
automobile_loans
